# %% [markdown]
# # **BootCamp DS - 20243**
# ## **Actividad 3**
# ### **Presentado por:** Diego Chávez

# %% [markdown]
# ### Contexto:
# En esta actividad veremos algunas preguntas de interés las cuales me gustaría resolver mediante el uso de algoritmos de ML y análisis exploratorios de la información, además de unas correcciones a los gráficos de la **actividad 2**.

# %% [markdown]
# ### 1. Preguntas de interés
#
# Aunque algunas preguntas suenen un tanto obvias, sería interesante analizar su respuesta con disintos algoritmos de ML. Así, veamos las preguntas a resolver:
#
# * ¿Cuál será el producto más vendido en 2025?
# * ¿Será mayor o menor el número de ventas a colocar para el 2025 en comparación con el periodo anterior?
# * ¿Cuántas ventas se tendrán para el año 2025, por trimestre y semestre?
# * ¿Qué tan viable es que un cliente realice el pago de su préstamo basado en préstamos anteriores?
# * ¿Sería una buena idea ampliar o disminur los montos prestados?
# * ¿Existe algún patrón estacional en la ventas, como navidad, año nuevo, etc?
#
# Con estas breves preguntas daré inicio al proyecto y a medida que avance iré añadiendo más preguntas o hipótesis de interés para mí y la empresa.

# %% [markdown]
# ### 2. Mejora en los gráficos

# %%
# importamos la librerías
import pandas as pd
import numpy as np
import os

# %%
dataset = pd.read_excel(r"C:/Users/Diego Chavez/Desktop/BIT/BootCamp/BD.xlsx")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualización bivariada: Gráfico de dispersión
plt.figure(figsize=(8, 6))
sns.scatterplot(data=dataset, x='Monto Bruto Prestado', y='Salario Reportado del cliente', hue='TIPO', palette='viridis')
plt.title('Relación entre Monto Prestado y Salario por Tipo')
plt.xlabel('Monto')
plt.ylabel('Salario')
plt.show()
